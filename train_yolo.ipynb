# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/yolo_train/darknet
# Out:
# /content/drive/MyDrive/yolo_train/darknet

# %%
# !ls
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results

# %%
# !chmod +x /content/drive/MyDrive/yolo_train/darknet

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./examples/detector.c -o obj/detector.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN obj/captcha.o obj/lsd.o obj/super.o obj/art.o obj/tag.o obj/cifar.o obj/go.o obj/rnn.o obj/segmenter.o obj/regressor.o obj/classifier.o obj/coco.o obj/yolo.o obj/detector.o obj/nightmare.o obj/instance-segmenter.o obj/darknet.o libdarknet.a -o darknet -lm -pthread  `pkg-config --libs opencv` -lstdc++ -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lcudnn -lstdc++  libdarknet.a

# %%
# %cd /content/drive/MyDrive/yolo_train
# Out:
# /content/drive/MyDrive/yolo_train

# %%
# !ls
# Out:
#  backup					    custom_data     darknet
# 'Bản sao của Colaboratory chào mừng bạn!'   custom_weight

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !nvidia-smi
# Out:
# Sun Jan  9 06:49:25 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !dos2unix ./custom_data/train.txt
# !dos2unix ./custom_data/test.txt
# !dos2unix ./custom_data/labelled_data.data
# !dos2unix ./custom_data/classes.names
# !dos2unix ./darknet/cfg/yolov3_custom.cfg
# Out:
# dos2unix: converting file ./custom_data/train.txt to Unix format...
# dos2unix: converting file ./custom_data/test.txt to Unix format...
# dos2unix: converting file ./custom_data/labelled_data.data to Unix format...
# dos2unix: converting file ./custom_data/classes.names to Unix format...
# dos2unix: converting file ./darknet/cfg/yolov3_custom.cfg to Unix format...

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000211, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000019, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.754861, Class: 0.986193, Obj: 0.699921, No Obj: 0.000729, .5R: 1.000000, .75R: 0.500000,  count: 4
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000005, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000674, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.694807, Class: 0.998509, Obj: 0.862893, No Obj: 0.000642, .5R: 1.000000, .75R: 0.000000,  count: 4
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000004, .5R: -nan, .75R: -nan,  count: 0
# ...

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg backup/yolov3_custom_900.weights -dont_show
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.867034, Class: 0.999155, Obj: 0.962908, No Obj: 0.001213, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.913633, Class: 0.999065, Obj: 0.991712, No Obj: 0.000978, .5R: 1.000000, .75R: 1.000000,  count: 3
# Region 94 Avg IOU: 0.905303, Class: 0.999884, Obj: 0.998551, No Obj: 0.000060, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.894394, Class: 0.999693, Obj: 0.999296, No Obj: 0.000972, .5R: 1.000000, .75R: 1.000000,  count: 4
# ...
